# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilJ2712/Data-Science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Data Manipulation Library

import pandas as pd
import numpy as np

# Import Data Visualization Library

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define a Series : 1-D Array

a = pd.Series([1,2,3,4,5])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
b = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(b)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
b = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
b
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Using Concept Of Indexing
print(a.dtype)
print(a[3])
print(b['d'])
# Out:
# int64
# 4
# 4

# %%
# 2D
c = pd.DataFrame({'India':[2000],'USA' :[3000],
         'UK':[30000]
})
print(c)
# Out:
#    India   USA     UK
# 0   2000  3000  30000

# %%
# Create Student Dsatabase
database = {'Name':['Nikhil', 'Aniket', 'Mihir', 'Tanvi', 'Hemangi'],
            'Age' :[10,11,12,13,14],
            'Marks':[34,56,67,34,56],
            'CGPA':[8,6,9,6,8]
    }

# Create a Variable df: Which will store dataframe
df = pd.DataFrame(database)
print(df)
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[df['Name'] == 'Tanvi']
# Out:
#     Name  Age  Marks  CGPA
# 3  Tanvi   13     34     6

# %%
df[df['Name'] == 'Nikhil']
# Out:
#      Name  Age  Marks  CGPA
# 0  Nikhil   10     34     8

# %%
# Using agg() : Aggregate Function

df['Marks'].agg(['min','max','mean'])
# Out:
# min     34.0
# max     67.0
# mean    49.4
# Name: Marks, dtype: float64

# %%
df[df['Marks'] == max(df['Marks'])]
# Out:
#     Name  Age  Marks  CGPA
# 2  Mihir   12     67     9

# %%
'''
Logical Operators in Python Programming
== comparison operator
< less than
> greater than
<= less than equal to
>= greater than equal to
!= not equal to
= Assignment Operator
& = And Logic Operator
| = Or Logic Operator
~ = Not Logic Operator or Tilde Operator

'''
df[df['CGPA'] <= 8]
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[~(df['CGPA'] < 8) | (df['Marks'] > 30)]
# Out:
#       Name  Age  Marks  CGPA
# 0   Nikhil   10     34     8
# 1   Aniket   11     56     6
# 2    Mihir   12     67     9
# 3    Tanvi   13     34     6
# 4  Hemangi   14     56     8

# %%
df[(df['CGPA'] < 8) & (df['Marks'] > 30)]
# Out:
#      Name  Age  Marks  CGPA
# 1  Aniket   11     56     6
# 3   Tanvi   13     34     6

# %%
df[df['Marks'] == 67]
# Out:
#     Name  Age  Marks  CGPA
# 2  Mihir   12     67     9

# %%
df[df['CGPA'] == 6]
# Out:
#      Name  Age  Marks  CGPA
# 1  Aniket   11     56     6
# 3   Tanvi   13     34     6

# %%
# Checking DataFrame Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      int64
#  3   CGPA    5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
# This code will check if any missing values in Dataset

df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    0
# CGPA     0
# dtype: int64

# %%
print(df['Marks'].sum())
print(df['Marks'].mean())
print(df['Marks'].max())
print(df['Marks'].min())
print(df['Marks'].nunique())
print(df['Marks'].unique())
print(df['Name'].value_counts())
print(df['Marks'].value_counts())
# Out:
# 247
# 49.4
# 67
# 34
# 3
# [34 56 67]
# Name
# Nikhil     1
# Aniket     1
# Mihir      1
# Tanvi      1
# Hemangi    1
# Name: count, dtype: int64
# Marks
# 34    2
# 56    2
# 67    1
# Name: count, dtype: int64

# %%
# Plotting Bar Plot using Matplotlib:

plt.bar(df['Name'],df['CGPA'],color='g')
plt.title('CGPA Vs Name')
plt.ylim(0,15)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colormaps = ['red', 'green', 'magenta', 'black', 'cyan']
sns.barplot(x=df['Name'], y=df['CGPA'], palette=colormaps)
plt.xlabel('Name')
plt.ylabel('CGPA')
plt.title('CGPA Vs Name')
plt.ylim(0, 15)
plt.show()
# Out:
# <ipython-input-101-f467a25da391>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Name'], y=df['CGPA'], palette=colormaps)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colormaps = ['red', 'green', 'magenta', 'black', 'cyan']  # custom colors

sns.barplot(x='Name', y='CGPA', data=df, hue='Name', palette=colormaps, legend=False)
plt.xlabel('Name')
plt.ylabel('CGPA')
plt.title('CGPA Vs Name')
plt.ylim(0, 15)
plt.show()

# %%
sns.scatterplot(x=df['Age'], y=df['CGPA'],hue=df['Marks'])
sns.regplot(x=df['Age'], y=df['CGPA'])
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'CGPA'], dtype='object')

# %%
sns.scatterplot(x= df['Marks'],y= df['CGPA'], hue = df['Age'])
# Out:
# <Axes: xlabel='Marks', ylabel='CGPA'>

# %%
sns.scatterplot(x=df['Marks'], y=df['CGPA'], hue=df['Age'])
plt.axhline(8, linestyle='--')
plt.axvline(56, linestyle='--', color='green')
plt.title('Data Insights')
plt.show()

# %%
# Create Company Database
Company = {'Name':['Nikhil', 'Aniket', 'Mihir', 'Tanvi', 'Hemangi', 'Yash', 'Disha','Shreya'],
            'Salary' :[50000,60000,70000,71000,89000,78000,67000,55000],
            'No_of_Exp':[1,2,3,4,5,6,7,8],
            'Domain':['Tech','Nontech','HR','R&D', 'Tech', 'Nontech', 'HR','Tech'],
            'Age':[20,21,22,23,24,25,26,27],
            'Gender':['M','M','M','F','F','M','F','F']
    }

 # Create a Variable df: Which will store dataframe
df = pd.DataFrame(Company)
print(df)
# Out:
#       Name  Salary  No_of_Exp   Domain  Age Gender
# 0   Nikhil   50000          1     Tech   20      M
# 1   Aniket   60000          2  Nontech   21      M
# 2    Mihir   70000          3       HR   22      M
# 3    Tanvi   71000          4      R&D   23      F
# 4  Hemangi   89000          5     Tech   24      F
# 5     Yash   78000          6  Nontech   25      M
# 6    Disha   67000          7       HR   26      F
# 7   Shreya   55000          8     Tech   27      F

# %%
# Checking DataFrame Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       8 non-null      object
#  1   Salary     8 non-null      int64
#  2   No_of_Exp  8 non-null      int64
#  3   Domain     8 non-null      object
#  4   Age        8 non-null      int64
#  5   Gender     8 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 516.0+ bytes

# %%
# Evaluting the Max Number Of Exp From The Dataset

df[df['No_of_Exp'] == max(df['No_of_Exp'])]
# Out:
#      Name  Salary  No_of_Exp Domain  Age Gender
# 7  Shreya   55000          8   Tech   27      F

# %%
# Evaluting the Max Number Of Exp From The Dataset

df['No_of_Exp'].max()
# Out:
# 8

# %%
# Evaluting the Min Number Of Exp From The Dataset

df[df['No_of_Exp'] == min(df['No_of_Exp'])]
# Out:
#      Name  Salary  No_of_Exp Domain  Age Gender
# 0  Nikhil   50000          1   Tech   20      M

# %%
# Evaluting the Min Number Of Exp From The Dataset

df['No_of_Exp'].min()
# Out:
# 1

# %%
# Evaluting the Mean Number Of Exp From The Dataset

df['No_of_Exp'].mean()
# Out:
# np.float64(4.5)

# %%
# Evaluting the data of Female Employee

f= df[df['Gender'] == 'F']
print(f)
# Out:
#       Name  Salary  No_of_Exp Domain  Age Gender
# 3    Tanvi   71000          4    R&D   23      F
# 4  Hemangi   89000          5   Tech   24      F
# 6    Disha   67000          7     HR   26      F
# 7   Shreya   55000          8   Tech   27      F

# %%
# Max Salary Of Female

f['Salary'].max()
# Out:
# 89000

# %%
# List the Maximum salary of Female
f[f['Salary'] == 89000]
# Out:
#       Name  Salary  No_of_Exp Domain  Age Gender
# 4  Hemangi   89000          5   Tech   24      F

# %%
f = df[df['Gender'] == 'F']
f['Salary'].max()
f[f['Salary'] == 89000]
# Out:
#       Name  Salary  No_of_Exp Domain  Age Gender
# 4  Hemangi   89000          5   Tech   24      F

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    4
# F    4
# Name: count, dtype: int64
