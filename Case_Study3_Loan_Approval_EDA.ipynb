# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilJ2712/Data-Science/blob/main/Case_Study3_Loan_Approval_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Data Manipulation Library
import pandas as pd
import numpy as np

# Importing Data Visualization Library
import seaborn as sns
import matplotlib.pyplot as plt

# Import FilterWarnings Library
import warnings
warnings.filterwarnings('ignore')

# Import Logging
import logging
logging.basicConfig(level = logging.INFO,
                    filename ='model.log',
                    format = '%(asctime)s) - %(levelname)s - %(message)s',
                    filemode = 'w')
logging.info('Model Started')

# %%
# Importing Data using Pandas Function
df =pd.read_csv('/content/loan_data - loan_data.csv')

# It will print Shuffle 100% Dataset
df.sample(frac = 1)

# df.head() # it will print top five rows
# df.tail() # it will print bottom five rows
# Out:
#        person_age person_gender person_education  person_income  \
# 7018           23          male         Bachelor          73114
# 13006          23          male         Bachelor         102990
# 16239          24          male        Associate          29542
# 27174          29        female      High School         151288
# 35285          26          male           Master          72987
# ...           ...           ...              ...            ...
# 28805          29          male      High School          22504
# 11531          22          male           Master          79093
# 30493          39          male      High School          68471
# 37306          23        female           Master          67974
# 3109           21        female           Master          17383
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 7018                2                  RENT       6200  DEBTCONSOLIDATION
# 13006               0                  RENT      12000           PERSONAL
# 16239               1              MORTGAGE       7000    HOMEIMPROVEMENT
# 27174               7              MORTGAGE      25000           PERSONAL
# 35285               2              MORTGAGE       5000           PERSONAL
# ...               ...                   ...        ...                ...
# 28805               3                  RENT       6400  DEBTCONSOLIDATION
# 11531               0                  RENT      10000  DEBTCONSOLIDATION
# 30493              19              MORTGAGE       6000    HOMEIMPROVEMENT
# 37306               0                  RENT       5481          EDUCATION
# 3109                0                  RENT       3500            VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 7018           10.65                 0.08                           3
# 13006          10.37                 0.12                           4
# 16239          10.38                 0.24                           4
# 27174          10.62                 0.17                           8
# 35285           7.43                 0.07                           5
# ...              ...                  ...                         ...
# 28805          10.37                 0.28                           6
# 11531          10.00                 0.13                           2
# 30493          11.36                 0.09                          13
# 37306           9.65                 0.08                           3
# 3109            9.96                 0.20                           2
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 7018            642                            Yes            0
# 13006           638                             No            0
# 16239           628                             No            0
# 27174           688                             No            0
# 35285           622                            Yes            0
# ...             ...                            ...          ...
# 28805           686                             No            1
# 11531           591                            Yes            0
# 30493           552                            Yes            0
# 37306           627                            Yes            0
# 3109            694                             No            1
#
# [45000 rows x 14 columns]

# %%
# Problem Definition: Loan Default Prediction
'''
This dataset contains information related to personal and loan attributes of individuals who have applied for loans. The objective is to predict whether a client will default on their loan based on their demographic, financial, and credit history details.

The target variable is loan_status, where:

1 indicates the loan was repaid successfully (non-default),

0 indicates the client defaulted on the loan.


 X (independent variables) include:

Demographic: person_age, person_gender, person_education

Financial: person_income, person_emp_exp, person_home_ownership

Loan details: loan_amnt, loan_intent, loan_int_rate, loan_percent_income

Credit info: cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file

y (target variable): loan_status (binary classification — Default or No Default)


Objective:
To build a classification model that can help financial institutions or lending platforms assess the risk of a loan default before approval. This will help reduce bad debt and improve decision-making in the loan underwriting process.

'''
# Checking Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  int64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  int64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  int64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  int64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 4.8+ MB

# %%
# Checking Null Values Present in Dataset
# The following Graph shows, we dont have any missing value present in any of the coloumn
df.isnull().sum().plot(kind = 'barh') # First Method
# sns.heatmap(df.isnull(),cmap='coolwarm',vmin=-1,vmax=1,center =0) # Second method
# df.isnull().sum().plot(kind = 'bar',cmap = 'viridis') # Third Method
plt.title('Null Values Information')
plt.show()

# %%
# Split the Dataset Into Categorical and Numerical
categorical_col = df.select_dtypes(include ='object')
categorical_col
# Out:
#       person_gender person_education person_home_ownership        loan_intent  \
# 0            female           Master                  RENT           PERSONAL
# 1            female      High School                   OWN          EDUCATION
# 2            female      High School              MORTGAGE            MEDICAL
# 3            female         Bachelor                  RENT            MEDICAL
# 4              male           Master                  RENT            MEDICAL
# ...             ...              ...                   ...                ...
# 44995          male        Associate                  RENT            MEDICAL
# 44996        female        Associate                  RENT    HOMEIMPROVEMENT
# 44997          male        Associate                  RENT  DEBTCONSOLIDATION
# 44998          male         Bachelor                  RENT          EDUCATION
# 44999          male      High School                  RENT  DEBTCONSOLIDATION
#
#       previous_loan_defaults_on_file
# 0                                 No
# 1                                Yes
# 2                                 No
# 3                                 No
# 4                                 No
# ...                              ...
# 44995                             No
# 44996                             No
# 44997                             No
# 44998                             No
# 44999                             No
#
# [45000 rows x 5 columns]

# %%
numerical_col = df.select_dtypes(exclude ='object')
numerical_col
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0              22          71948               0      35000          16.02
# 1              21          12282               0       1000          11.14
# 2              25          12438               3       5500          12.87
# 3              23          79753               0      35000          15.23
# 4              24          66135               1      35000          14.27
# ...           ...            ...             ...        ...            ...
# 44995          27          47971               6      15000          15.66
# 44996          37          65800              17       9000          14.07
# 44997          33          56942               7       2771          10.02
# 44998          29          33164               4      12000          13.23
# 44999          24          51609               1       6665          17.05
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                     0.49                           3           561
# 1                     0.08                           2           504
# 2                     0.44                           3           635
# 3                     0.44                           2           675
# 4                     0.53                           4           586
# ...                    ...                         ...           ...
# 44995                 0.31                           3           645
# 44996                 0.14                          11           621
# 44997                 0.05                          10           668
# 44998                 0.36                           6           604
# 44999                 0.13                           3           628
#
#        loan_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 44995            1
# 44996            1
# 44997            1
# 44998            1
# 44999            1
#
# [45000 rows x 9 columns]

# %%
# Exploratory Data Analysis:
# 1.Univariate Analysis
'''
Step1: Create a Blank List : stats[]
Step2: Create Dictionary using OrderedDict
Step3 : Append list with Dictionary
Step4: Convert List into DataFrame

'''
from collections import OrderedDict
import pandas as pd

stats = []

for i in numerical_col.columns:
  numerical_stats = OrderedDict({
     'Feature': i,
      'Count':df[i].count(),
      'Minimum':df[i].min(),
      'Maximum':df[i].max(),
      'Mean':df[i].mean(),
      'Median':df[i].median(),
      'Q1':df[i].quantile(0.25),
      'Q3':df[i].quantile(0.75),
      'IQR':df[i].quantile(0.75)-df[i].quantile(0.25),
      'Standard Deviation':df[i].std(),
      'Kurtosis':df[i].kurt(),
      'Skewness':df[i].skew(),
      'Range':df[i].max()-df[i].min(),
      'Variance':df[i].var()


  })
  stats.append(numerical_stats)
  report = pd.DataFrame(stats)

report
# Out:
#                       Feature  Count  Minimum     Maximum          Mean  \
# 0                  person_age  45000    20.00      144.00     27.764178
# 1               person_income  45000  8000.00  7200766.00  80319.053222
# 2              person_emp_exp  45000     0.00      125.00      5.410333
# 3                   loan_amnt  45000   500.00    35000.00   9583.157556
# 4               loan_int_rate  45000     5.42       20.00     11.006606
# 5         loan_percent_income  45000     0.00        0.66      0.139725
# 6  cb_person_cred_hist_length  45000     2.00       30.00      5.867489
# 7                credit_score  45000   390.00      850.00    632.608756
# 8                 loan_status  45000     0.00        1.00      0.222222
#
#      Median        Q1        Q3       IQR  Standard Deviation     Kurtosis  \
# 0     26.00     24.00     30.00      6.00            6.045108    18.649449
# 1  67048.00  47204.00  95789.25  48585.25        80422.498632  2398.684769
# 2      4.00      1.00      8.00      7.00            6.063532    19.168324
# 3   8000.00   5000.00  12237.25   7237.25         6314.886691     1.351215
# 4     11.01      8.59     12.99      4.40            2.978808    -0.420335
# 5      0.12      0.07      0.19      0.12            0.087212     1.082416
# 6      4.00      3.00      8.00      5.00            3.879702     3.725945
# 7    640.00    601.00    670.00     69.00           50.435865     0.203022
# 8      0.00      0.00      0.00      0.00            0.415744    -0.214176
#
#     Skewness       Range      Variance
# 0   2.548154      124.00  3.654333e+01
# 1  34.137583  7192766.00  6.467778e+09
# 2   2.594917      125.00  3.676642e+01
# 3   1.179731    34500.00  3.987779e+07
# 4   0.213784       14.58  8.873299e+00
# 5   1.034512        0.66  7.605987e-03
# 6   1.631720       28.00  1.505209e+01
# 7  -0.610261      460.00  2.543776e+03
# 8   1.336351        1.00  1.728433e-01

# %%
plt.figure(figsize = (5,5))
sns.boxenplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
# Distribution of Loan Status

'''
Data Insights:
77.78 % people Not Approved their Loan Status From Bank
22.22 % people Approved their Loan Status From Bank

'''
df['loan_status'].value_counts().plot(kind ='pie',autopct ='%1.2f',explode = [0.02,0.02])
plt.title('Distribution of Loan Status')
plt.show()

# %%
# Gender Disrtibution

df['person_gender'].value_counts().plot(kind ='bar')
plt.title('Distribution of Gender')
plt.show()

# %%
# Loan status based on gender
# Loan is approved and Gender must be male
loan_status_approved_male=df[(df['loan_status'] == 1) & (df['person_gender'] == 'male')]
loan_status_approved_male
# Out:
#        person_age person_gender person_education  person_income  \
# 4              24          male           Master          66135
# 12             23          male         Bachelor         114860
# 13             26          male           Master         130713
# 18             23          male         Bachelor         136628
# 24             22          male         Bachelor          97420
# ...           ...           ...              ...            ...
# 44991          24          male      High School          37786
# 44995          27          male        Associate          47971
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 4                   1                  RENT      35000            MEDICAL
# 12                  3                  RENT      35000            VENTURE
# 13                  0                  RENT      35000          EDUCATION
# 18                  0                  RENT      35000  DEBTCONSOLIDATION
# 24                  1                  RENT      33950           PERSONAL
# ...               ...                   ...        ...                ...
# 44991               0              MORTGAGE      13500          EDUCATION
# 44995               6                  RENT      15000            MEDICAL
# 44997               7                  RENT       2771  DEBTCONSOLIDATION
# 44998               4                  RENT      12000          EDUCATION
# 44999               1                  RENT       6665  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 4              14.27                 0.53                           4
# 12              7.90                 0.30                           2
# 13             18.39                 0.27                           4
# 18             18.25                 0.26                           4
# 24             14.54                 0.35                           4
# ...              ...                  ...                         ...
# 44991          13.43                 0.36                           4
# 44995          15.66                 0.31                           3
# 44997          10.02                 0.05                          10
# 44998          13.23                 0.36                           6
# 44999          17.05                 0.13                           3
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 4               586                             No            1
# 12              573                             No            1
# 13              708                             No            1
# 18              709                             No            1
# 24              691                             No            1
# ...             ...                            ...          ...
# 44991           612                             No            1
# 44995           645                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [5515 rows x 14 columns]

# %%
# Loan is approved and Gender must be female
loan_status_approved_female=df[(df['loan_status'] == 1) & (df['person_gender'] == 'female')]
loan_status_approved_female
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 5              21        female      High School          12951
# 6              26        female         Bachelor          93471
# ...           ...           ...              ...            ...
# 44988          28        female        Associate          49170
# 44992          23        female         Bachelor          40925
# 44993          27        female      High School          35512
# 44994          24        female        Associate          31924
# 44996          37        female        Associate          65800
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 0                   0                  RENT      35000         PERSONAL
# 2                   3              MORTGAGE       5500          MEDICAL
# 3                   0                  RENT      35000          MEDICAL
# 5                   0                   OWN       2500          VENTURE
# 6                   1                  RENT      35000        EDUCATION
# ...               ...                   ...        ...              ...
# 44988               4                  RENT      10401  HOMEIMPROVEMENT
# 44992               0                  RENT       9000         PERSONAL
# 44993               4                  RENT       5000         PERSONAL
# 44994               2                  RENT      12229          MEDICAL
# 44996              17                  RENT       9000  HOMEIMPROVEMENT
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                           3
# 2              12.87                 0.44                           3
# 3              15.23                 0.44                           2
# 5               7.14                 0.19                           2
# 6              12.42                 0.37                           3
# ...              ...                  ...                         ...
# 44988          11.97                 0.21                           6
# 44992          11.01                 0.22                           4
# 44993          15.83                 0.14                           5
# 44994          10.70                 0.38                           4
# 44996          14.07                 0.14                          11
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 2               635                             No            1
# 3               675                             No            1
# 5               532                             No            1
# 6               701                             No            1
# ...             ...                            ...          ...
# 44988           677                             No            1
# 44992           487                             No            1
# 44993           505                             No            1
# 44994           678                             No            1
# 44996           621                             No            1
#
# [4485 rows x 14 columns]

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_approved_male['person_income'], y = loan_status_approved_male['loan_amnt'],hue =loan_status_approved_male['loan_intent'])
plt.title('Loan Approved For Male based on loan_intent')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_approved_female['person_income'], y = loan_status_approved_female['loan_amnt'],hue =loan_status_approved_female['loan_intent'])
plt.title('Loan Approved For FeMale based on loan_intent ')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_approved_male['person_income'], y = loan_status_approved_male['loan_amnt'],hue =loan_status_approved_male['previous_loan_defaults_on_file'])
plt.title('Loan Approved For Male based on previous_loan_defaults_on_file ')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_approved_female['person_income'], y = loan_status_approved_female['loan_amnt'],hue =loan_status_approved_female['previous_loan_defaults_on_file'])
plt.title('Loan Approved For FeMale based on previous_loan_defaults_on_file ')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
loan_status_notapproved_male=df[(df['loan_status'] == 0) & (df['person_gender'] == 'male')]
loan_status_notapproved_male
# Out:
#        person_age person_gender person_education  person_income  \
# 16             23          male         Bachelor         144943
# 20             25          male         Bachelor         195718
# 21             25          male      High School         165792
# 27             23          male      High School          14293
# 31             25          male         Bachelor         144855
# ...           ...           ...              ...            ...
# 42098          26          male        Associate          85414
# 42099          25          male         Bachelor         165605
# 42100          27          male        Associate          96196
# 42103          36          male         Bachelor          60006
# 42105          43          male        Doctorate          93061
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 16                  0                  RENT      35000   EDUCATION
# 20                  0                  RENT      35000     VENTURE
# 21                  4                  RENT      34800    PERSONAL
# 27                  0                   OWN       1400    PERSONAL
# 31                  1                  RENT      32000     VENTURE
# ...               ...                   ...        ...         ...
# 42098               2                  RENT      12000   EDUCATION
# 42099               0              MORTGAGE       9989     VENTURE
# 42100               1              MORTGAGE       8000     MEDICAL
# 42103              15                   OWN       2755     MEDICAL
# 42105              21              MORTGAGE      12966     VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 16              7.90                 0.24                           4
# 20              7.49                 0.18                           4
# 21             16.77                 0.21                           2
# 27              9.32                 0.10                           3
# 31              6.62                 0.22                           2
# ...              ...                  ...                         ...
# 42098           6.72                 0.14                           4
# 42099           5.92                 0.06                           4
# 42100           6.38                 0.08                           8
# 42103           8.92                 0.05                           9
# 42105          14.40                 0.14                          12
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 16              663                             No            0
# 20              684                            Yes            0
# 21              662                             No            0
# 27              607                             No            0
# 31              586                            Yes            0
# ...             ...                            ...          ...
# 42098           509                            Yes            0
# 42099           648                             No            0
# 42100           593                            Yes            0
# 42103           609                            Yes            0
# 42105           690                            Yes            0
#
# [19326 rows x 14 columns]

# %%
loan_status_notapproved_female=df[(df['loan_status'] == 0) & (df['person_gender'] == 'female')]
loan_status_notapproved_female
# Out:
#        person_age person_gender person_education  person_income  \
# 1              21        female      High School          12282
# 14             23        female        Associate         138998
# 15             23        female           Master         600891
# 23             24        female         Bachelor          13866
# 33             25        female      High School         368115
# ...           ...           ...              ...            ...
# 42101          27        female      High School         107051
# 42102          28        female        Associate          36900
# 42104          25        female         Bachelor          64146
# 42106          28        female      High School         110291
# 42107          26        female         Bachelor          66849
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 1                   0                   OWN       1000          EDUCATION
# 14                  0                  RENT      35000          EDUCATION
# 15                  5              MORTGAGE      30000  DEBTCONSOLIDATION
# 23                  0                   OWN       1500           PERSONAL
# 33                  3                  RENT      24250  DEBTCONSOLIDATION
# ...               ...                   ...        ...                ...
# 42101               2              MORTGAGE      24000            MEDICAL
# 42102               6                  RENT       2000            VENTURE
# 42104               2              MORTGAGE       7200            VENTURE
# 42106               7                  RENT      13453            VENTURE
# 42107               1                  RENT       4000           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              11.14                 0.08                           2
# 14              7.90                 0.25                           4
# 15             10.65                 0.05                           3
# 23              7.29                 0.11                           3
# 33             13.85                 0.07                           3
# ...              ...                  ...                         ...
# 42101          11.21                 0.22                           5
# 42102           5.77                 0.05                           6
# 42104          10.28                 0.11                           3
# 42106          13.29                 0.12                           6
# 42107          10.99                 0.06                           4
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1               504                            Yes            0
# 14              583                             No            0
# 15              670                            Yes            0
# 23              600                            Yes            0
# 33              567                            Yes            0
# ...             ...                            ...          ...
# 42101           611                            Yes            0
# 42102           526                            Yes            0
# 42104           625                            Yes            0
# 42106           631                            Yes            0
# 42107           550                            Yes            0
#
# [15674 rows x 14 columns]

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_notapproved_male['person_income'], y = loan_status_notapproved_male['loan_amnt'],hue =loan_status_notapproved_male['previous_loan_defaults_on_file'])
plt.title('Loan NotApproved For Male based on previous_loan_defaults_on_file')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_notapproved_female['person_income'], y = loan_status_notapproved_female['loan_amnt'],hue =loan_status_notapproved_female['previous_loan_defaults_on_file'])
plt.title('Loan NotApproved For FeMale based on previous_loan_defaults_on_file')
plt.axvline(300000,linestyle='--',c = 'b')
plt.axhline(25000,linestyle='--',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_notapproved_male['person_income'],y = loan_status_notapproved_male['loan_amnt'],hue = loan_status_notapproved_male['loan_intent'])
plt.title('Loan NotApproved For Male based on loan_intent')
plt.axvline(300000,linestyle = '--',c = 'b')
plt.axhline(25000,linestyle = ':',c = 'b')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = loan_status_notapproved_female['person_income'],y = loan_status_notapproved_female['loan_amnt'],hue = loan_status_notapproved_female['loan_intent'])
plt.title('Loan NotApproved For FeMale based on loan_intent')
plt.axvline(300000,linestyle = '--',c = 'b')
plt.axhline(25000,linestyle = ':',c = 'b')
plt.show()
